# %%
pip install pymysql
# Out:
# Collecting pymysql
#   Downloading pymysql-1.1.2-py3-none-any.whl.metadata (4.3 kB)
# Downloading pymysql-1.1.2-py3-none-any.whl (45 kB)
# Installing collected packages: pymysql
# Successfully installed pymysql-1.1.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import dotenv
import sqlalchemy
import pandas as pd
import numpy as np

# %%
dotenv.load_dotenv(override=True, dotenv_path="credenziali.env")
# Out:
# True

# %%
username = os.getenv('username')
password = os.getenv('password')
host = os.getenv('host')
dbname = os.getenv('dbname')

# %%
connection_string =f'mysql+pymysql://{username}:{password}@{host}/{dbname}'
print (connection_string)
# Out:
# mysql+pymysql://studente_dapt:Ep1c0d3!!D4t4**4n4lys1s@epicode-data-pt-mysql.cvetyjye2qbl.eu-central-1.rds.amazonaws.com/AdventureWorksDW

# %%
db_engine=sqlalchemy.create_engine(connection_string)

# %%
import pandas as pd

# %%
query = 'select * from dimproduct'
df=pd.read_sql(query,db_engine)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 606 entries, 0 to 605
# Data columns (total 36 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ProductKey             606 non-null    int64
#  1   ProductAlternateKey    606 non-null    object
#  2   ProductSubcategoryKey  397 non-null    float64
#  3   WeightUnitMeasureCode  282 non-null    object
#  4   SizeUnitMeasureCode    253 non-null    object
#  5   EnglishProductName     606 non-null    object
#  6   SpanishProductName     606 non-null    object
#  7   FrenchProductName      606 non-null    object
#  8   StandardCost           397 non-null    float64
#  9   FinishedGoodsFlag      606 non-null    int64
#  10  Color                  606 non-null    object
#  11  SafetyStockLevel       606 non-null    int64
#  12  ReorderPoint           606 non-null    int64
#  13  ListPrice              395 non-null    float64
#  14  Size                   299 non-null    object
#  15  SizeRange              606 non-null    object
#  16  Weight                 282 non-null    float64
#  17  DaysToManufacture      606 non-null    int64
#  18  ProductLine            380 non-null    object
#  19  DealerPrice            395 non-null    float64
#  20  Class                  330 non-null    object
#  21  Style                  301 non-null    object
#  22  ModelName              397 non-null    object
#  23  LargePhoto             606 non-null    object
#  24  EnglishDescription     396 non-null    object
#  25  FrenchDescription      396 non-null    object
#  26  ChineseDescription     396 non-null    object
#  27  ArabicDescription      396 non-null    object
#  28  HebrewDescription      396 non-null    object
#  29  ThaiDescription        396 non-null    object
#  30  GermanDescription      396 non-null    object
#  31  JapaneseDescription    396 non-null    object
#  32  TurkishDescription     396 non-null    object
#  33  StartDate              606 non-null    datetime64[ns]
#  34  EndDate                200 non-null    datetime64[ns]
#  35  Status                 406 non-null    object
# dtypes: datetime64[ns](2), float64(5), int64(5), object(24)
# memory usage: 170.6+ KB

# %%
query = 'select * from dimproduct'
df=pd.read_sql(query,db_engine)
df.index
# Out:
# RangeIndex(start=0, stop=606, step=1)

# %%
query = 'select * from dimproduct'
df=pd.read_sql(query,db_engine)
df.columns
# Out:
# Index(['ProductKey', 'ProductAlternateKey', 'ProductSubcategoryKey',
#        'WeightUnitMeasureCode', 'SizeUnitMeasureCode', 'EnglishProductName',
#        'SpanishProductName', 'FrenchProductName', 'StandardCost',
#        'FinishedGoodsFlag', 'Color', 'SafetyStockLevel', 'ReorderPoint',
#        'ListPrice', 'Size', 'SizeRange', 'Weight', 'DaysToManufacture',
#        'ProductLine', 'DealerPrice', 'Class', 'Style', 'ModelName',
#        'LargePhoto', 'EnglishDescription', 'FrenchDescription',
#        'ChineseDescription', 'ArabicDescription', 'HebrewDescription',
#        'ThaiDescription', 'GermanDescription', 'JapaneseDescription',
#        'TurkishDescription', 'StartDate', 'EndDate', 'Status'],
#       dtype='object')

# %%
query = 'select * from dimproduct'
df=pd.read_sql(query,db_engine)
df.shape
# Out:
# (606, 36)

# %%
query = 'select * from dimproduct'
df=pd.read_sql(query,db_engine)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 606 entries, 0 to 605
# Data columns (total 36 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ProductKey             606 non-null    int64
#  1   ProductAlternateKey    606 non-null    object
#  2   ProductSubcategoryKey  397 non-null    float64
#  3   WeightUnitMeasureCode  282 non-null    object
#  4   SizeUnitMeasureCode    253 non-null    object
#  5   EnglishProductName     606 non-null    object
#  6   SpanishProductName     606 non-null    object
#  7   FrenchProductName      606 non-null    object
#  8   StandardCost           397 non-null    float64
#  9   FinishedGoodsFlag      606 non-null    int64
#  10  Color                  606 non-null    object
#  11  SafetyStockLevel       606 non-null    int64
#  12  ReorderPoint           606 non-null    int64
#  13  ListPrice              395 non-null    float64
#  14  Size                   299 non-null    object
#  15  SizeRange              606 non-null    object
#  16  Weight                 282 non-null    float64
#  17  DaysToManufacture      606 non-null    int64
#  18  ProductLine            380 non-null    object
#  19  DealerPrice            395 non-null    float64
#  20  Class                  330 non-null    object
#  21  Style                  301 non-null    object
#  22  ModelName              397 non-null    object
#  23  LargePhoto             606 non-null    object
#  24  EnglishDescription     396 non-null    object
#  25  FrenchDescription      396 non-null    object
#  26  ChineseDescription     396 non-null    object
#  27  ArabicDescription      396 non-null    object
#  28  HebrewDescription      396 non-null    object
#  29  ThaiDescription        396 non-null    object
#  30  GermanDescription      396 non-null    object
#  31  JapaneseDescription    396 non-null    object
#  32  TurkishDescription     396 non-null    object
#  33  StartDate              606 non-null    datetime64[ns]
#  34  EndDate                200 non-null    datetime64[ns]
#  35  Status                 406 non-null    object
# dtypes: datetime64[ns](2), float64(5), int64(5), object(24)
# memory usage: 170.6+ KB

# %%
query = 'select * from dimproduct'
df=pd.read_sql(query,db_engine)
df.describe()
# Out:
#        ProductKey  ProductSubcategoryKey  StandardCost  FinishedGoodsFlag  \
# count   606.00000             397.000000    397.000000         606.000000
# mean    303.50000              12.128463    436.823073           0.655116
# min       1.00000               1.000000      0.860000           0.000000
# 25%     152.25000               2.000000     37.120000           0.000000
# 50%     303.50000              13.000000    204.630000           1.000000
# 75%     454.75000              16.000000    660.910000           1.000000
# max     606.00000              37.000000   2171.290000           1.000000
# std     175.08141               9.423328    497.343079           0.475723
#
#        SafetyStockLevel  ReorderPoint    ListPrice       Weight  \
# count        606.000000    606.000000   395.000000   282.000000
# mean         495.201320    371.400990   747.661544    56.193227
# min            4.000000      3.000000     2.290000     2.120000
# 25%          100.000000     75.000000    69.990000     2.680000
# 50%          500.000000    375.000000   364.090000    15.420000
# 75%         1000.000000    750.000000  1204.320000    24.130000
# max         1000.000000    750.000000  3578.270000  1050.000000
# std          364.007114    273.005336   838.708359   158.000652
#
#        DaysToManufacture  DealerPrice                      StartDate  \
# count         606.000000   395.000000                            606
# mean            1.201320   448.597060  2009-07-26 03:12:28.514851328
# min             0.000000     1.374000            2003-07-01 00:00:00
# 25%             0.000000    41.994000            2003-07-01 00:00:00
# 50%             1.000000   218.454000            2012-07-01 00:00:00
# 75%             1.000000   722.594900            2013-07-01 00:00:00
# max             4.000000  2146.962000            2013-07-01 00:00:00
# std             1.508893   503.225071                            NaN
#
#                    EndDate
# count                  200
# mean   2008-08-17 14:24:00
# min    2007-12-28 00:00:00
# 25%    2007-12-28 00:00:00
# 50%    2008-12-27 00:00:00
# 75%    2008-12-27 00:00:00
# max    2008-12-27 00:00:00
# std                    NaN

# %%
query = 'select * from dimproduct'
df=pd.read_sql(query,db_engine)
df.head()
# Out:
#    ProductKey ProductAlternateKey  ProductSubcategoryKey  \
# 0           1             AR-5381                    NaN
# 1           2             BA-8327                    NaN
# 2           3             BE-2349                    NaN
# 3           4             BE-2908                    NaN
# 4           5             BL-2036                    NaN
#
#   WeightUnitMeasureCode SizeUnitMeasureCode     EnglishProductName  \
# 0                  None                None        Adjustable Race
# 1                  None                None           Bearing Ball
# 2                  None                None        BB Ball Bearing
# 3                  None                None  Headset Ball Bearings
# 4                  None                None                  Blade
#
#   SpanishProductName FrenchProductName  StandardCost  FinishedGoodsFlag  ...  \
# 0                                                NaN                  0  ...
# 1                                                NaN                  0  ...
# 2                                                NaN                  0  ...
# 3                                                NaN                  0  ...
# 4                                                NaN                  0  ...
#
#   ChineseDescription  ArabicDescription  HebrewDescription  ThaiDescription  \
# 0               None               None               None             None
# 1               None               None               None             None
# 2               None               None               None             None
# 3               None               None               None             None
# 4               None               None               None             None
#
#   GermanDescription JapaneseDescription  TurkishDescription  StartDate  \
# 0              None                None                None 2003-07-01
# 1              None                None                None 2003-07-01
# 2              None                None                None 2003-07-01
# 3              None                None                None 2003-07-01
# 4              None                None                None 2003-07-01
#
#   EndDate   Status
# 0     NaT  Current
# 1     NaT  Current
# 2     NaT  Current
# 3     NaT  Current
# 4     NaT  Current
#
# [5 rows x 36 columns]

# %%
query = 'select * from dimproduct'
df=pd.read_sql(query,db_engine)
df.tail(8)
# Out:
#      ProductKey ProductAlternateKey  ProductSubcategoryKey  \
# 598         599          BK-M18B-48                    1.0
# 599         600          BK-M18B-52                    1.0
# 600         601             BB-7421                    5.0
# 601         602             BB-8107                    5.0
# 602         603             BB-9108                    5.0
# 603         604          BK-R19B-44                    2.0
# 604         605          BK-R19B-48                    2.0
# 605         606          BK-R19B-52                    2.0
#
#     WeightUnitMeasureCode SizeUnitMeasureCode      EnglishProductName  \
# 598                    LB                  CM  Mountain-500 Black, 48
# 599                    LB                  CM  Mountain-500 Black, 52
# 600                     G                None       LL Bottom Bracket
# 601                     G                None       ML Bottom Bracket
# 602                     G                None       HL Bottom Bracket
# 603                    LB                  CM      Road-750 Black, 44
# 604                    LB                  CM      Road-750 Black, 48
# 605                    LB                  CM      Road-750 Black, 52
#
#             SpanishProductName           FrenchProductName  StandardCost  \
# 598    Montaña: 500, negra, 48            VTT 500 noir, 48        294.58
# 599    Montaña: 500, negra, 52            VTT 500 noir, 52        294.58
# 600         Eje de pedalier GB          Axe de pédalier LL         23.97
# 601         Eje de pedalier GM          Axe de pédalier ML         44.95
# 602         Eje de pedalier GA          Axe de pédalier HL         53.94
# 603  Carretera: 750, negra, 44  Vélo de route 750 noir, 44        343.65
# 604  Carretera: 750, negra, 48  Vélo de route 750 noir, 48        343.65
# 605  Carretera: 750, negra, 52  Vélo de route 750 noir, 52        343.65
#
#      FinishedGoodsFlag  ...                              ChineseDescription  \
# 598                  1  ...  适合所有类型的使用，不论是公路骑乘还是越野。不论预算多少，均可称心如意。变速平稳，骑乘舒适。
# 599                  1  ...  适合所有类型的使用，不论是公路骑乘还是越野。不论预算多少，均可称心如意。变速平稳，骑乘舒适。
# 600                  1  ...                                             铬钢。
# 601                  1  ...                                   铝合金车圈；大直径脚蹬轴。
# 602                  1  ...                                      铝合金车圈和空心轴。
# 603                  1  ...               入门级成人自行车；确保越野旅行或公路骑乘的舒适。快拆式车毂和轮缘。
# 604                  1  ...               入门级成人自行车；确保越野旅行或公路骑乘的舒适。快拆式车毂和轮缘。
# 605                  1  ...               入门级成人自行车；确保越野旅行或公路骑乘的舒适。快拆式车毂和轮缘。
#
#                                      ArabicDescription  \
# 598  ملائمة لأي نوع من أنواع القيادة، سواءً على الط...
# 599  ملائمة لأي نوع من أنواع القيادة، سواءً على الط...
# 600                                  الفولاذ الكرومولي
# 601  فناجين من سبيكة الألومنيوم؛ ذات محور دوران كبي...
# 602             فناجين من سبيكة الألومنيوم ومحور أجوف.
# 603  إنها دراجة مناسبة للمبتدئين من البالغين؛ فهي ت...
# 604  إنها دراجة مناسبة للمبتدئين من البالغين؛ فهي ت...
# 605  إنها دراجة مناسبة للمبتدئين من البالغين؛ فهي ت...
#
#                                      HebrewDescription  \
# 598  מתאימים לכל סוג רכיבה, בדרכים סלולות ובשבילים ...
# 599  מתאימים לכל סוג רכיבה, בדרכים סלולות ובשבילים ...
# 600                     פלדת כרומולי (כרום-מולובדניום)
# 601           כיסויים מסגסוגת אלומיניום; ציר רחב-קוטר.
# 602               כיסויים מסגסוגת אלומיניום וציר חלול.
# 603  אופני מבוגרים למתחילים; מציעים רכיבה נוחה "מחו...
# 604  אופני מבוגרים למתחילים; מציעים רכיבה נוחה "מחו...
# 605  אופני מבוגרים למתחילים; מציעים רכיבה נוחה "מחו...
#
#                                        ThaiDescription  \
# 598  เหมาะสำหรับการขี่ทุกประเภท ทั้งบนถนนและแบบออฟโ...
# 599  เหมาะสำหรับการขี่ทุกประเภท ทั้งบนถนนและแบบออฟโ...
# 600                                        โลหะโครโมลี
# 601              ดุมอลูมิเนียมอัลลอยด์ แกนเพลาขนาดใหญ่
# 602                   ดุมอลูมิเนียมอัลลอยด์และเพลากลวง
# 603  จักรยานระดับเริ่มต้นสำหรับผู้ใหญ่ ให้ความสบายใ...
# 604  จักรยานระดับเริ่มต้นสำหรับผู้ใหญ่ ให้ความสบายใ...
# 605  จักรยานระดับเริ่มต้นสำหรับผู้ใหญ่ ให้ความสบายใ...
#
#                                      GermanDescription  \
# 598  Geeignet für Straße und Gelände. Für jedes Bud...
# 599  Geeignet für Straße und Gelände. Für jedes Bud...
# 600                                        Chromstahl.
# 601  Außenringe aus Aluminiumlegierung; Radachse mi...
# 602  Außenringe aus Aluminiumlegierung und hohle Ac...
# 603  Ein Erwachsenenrad für Einsteiger; bietet Komf...
# 604  Ein Erwachsenenrad für Einsteiger; bietet Komf...
# 605  Ein Erwachsenenrad für Einsteiger; bietet Komf...
#
#                                    JapaneseDescription  \
# 598    オンロードにもオフロードにも対応しながら、予算を選ばず、スムーズなシフトで快適な乗り心地です。
# 599    オンロードにもオフロードにも対応しながら、予算を選ばず、スムーズなシフトで快適な乗り心地です。
# 600                                              クロム鋼。
# 601                               アルミニウム合金カップ、大径スピンドル。
# 602                              アルミニウム合金カップとホロー アクスル。
# 603  エントリー レベルに対応する、クロスカントリーにも街への買い物にも快適な、大人の自転車。ハブ...
# 604  エントリー レベルに対応する、クロスカントリーにも街への買い物にも快適な、大人の自転車。ハブ...
# 605  エントリー レベルに対応する、クロスカントリーにも街への買い物にも快適な、大人の自転車。ハブ...
#
#                                     TurkishDescription  StartDate EndDate  \
# 598  Yolda veya arazide her tür sürüşe uygundur. He... 2013-07-01     NaT
# 599  Yolda veya arazide her tür sürüşe uygundur. He... 2013-07-01     NaT
# 600                                     Kromoli çelik. 2013-07-01     NaT
# 601  Alüminyum alaşımı orta göbekler; geniş çaplı mil. 2013-07-01     NaT
# 602    Alüminyum alaşımı orta göbekler ve içi boş aks. 2013-07-01     NaT
# 603  "Başlangıç seviyesinde yetişkin bisikleti, kır... 2013-07-01     NaT
# 604  "Başlangıç seviyesinde yetişkin bisikleti, kır... 2013-07-01     NaT
# 605  "Başlangıç seviyesinde yetişkin bisikleti, kır... 2013-07-01     NaT
#
#       Status
# 598  Current
# 599  Current
# 600  Current
# 601  Current
# 602  Current
# 603  Current
# 604  Current
# 605  Current
#
# [8 rows x 36 columns]

# %%
query = 'select * from dimproduct'
df=pd.read_sql(query,db_engine)
df.sample(4)
# Out:
#      ProductKey ProductAlternateKey  ProductSubcategoryKey  \
# 4             5             BL-2036                    NaN
# 358         359          BK-M68B-38                    1.0
# 110         111             LJ-5811                    NaN
# 48           49             HJ-5818                    NaN
#
#     WeightUnitMeasureCode SizeUnitMeasureCode      EnglishProductName  \
# 4                    None                None                   Blade
# 358                    LB                  CM  Mountain-200 Black, 38
# 110                  None                None    Thin-Jam Lock Nut 13
# 48                   None                None     Thin-Jam Hex Nut 14
#
#           SpanishProductName FrenchProductName  StandardCost  \
# 4                                                        NaN
# 358  Montaña: 200, negra, 38  VTT 200 noir, 38       1251.98
# 110                                                      NaN
# 48                                                       NaN
#
#      FinishedGoodsFlag  ...  \
# 4                    0  ...
# 358                  1  ...
# 110                  0  ...
# 48                   0  ...
#
#                                     ChineseDescription  \
# 4                                                 None
# 358  适用于环境恶劣的野外骑乘。可应对各种比赛的完美赛车。使用与 Mountain-100 相同的...
# 110                                               None
# 48                                                None
#
#                                      ArabicDescription  \
# 4                                                 None
# 358  لقيادة المحترفين في المناطق الريفية. دراجة مُث...
# 110                                               None
# 48                                                None
#
#                                      HebrewDescription  \
# 4                                                 None
# 358  לרכיבה רצינית בשטחים נידחים. מתאימים לכל רמה ש...
# 110                                               None
# 48                                                None
#
#                                        ThaiDescription  \
# 4                                                 None
# 358  สำหรับการขี่ในเส้นทางผจญภัย  เหมาะที่สุดสำหรับ...
# 110                                               None
# 48                                                None
#
#                                      GermanDescription  \
# 4                                                 None
# 358  Mountainbike für Profis. Perfekt für alle Schw...
# 110                                               None
# 48                                                None
#
#                                    JapaneseDescription  \
# 4                                                 None
# 358  バック カントリーまたは全レベルの競技用で、Mountain-100 と同じ HL フレーム...
# 110                                               None
# 48                                                None
#
#                                     TurkishDescription  StartDate EndDate  \
# 4                                                 None 2003-07-01     NaT
# 358  Gerçek arazi sürüşü. Tüm yarışma seviyeleri iç... 2013-07-01     NaT
# 110                                               None 2003-07-01     NaT
# 48                                                None 2003-07-01     NaT
#
#       Status
# 4    Current
# 358  Current
# 110  Current
# 48   Current
#
# [4 rows x 36 columns]

# %%
query = 'select * from dimproduct'
df=pd.read_sql(query,db_engine)
df.nunique()
# Out:
# ProductKey               606
# ProductAlternateKey      504
# ProductSubcategoryKey     37
# WeightUnitMeasureCode      2
# SizeUnitMeasureCode        1
# EnglishProductName       504
# SpanishProductName       238
# FrenchProductName        238
# StandardCost             131
# FinishedGoodsFlag          2
# Color                     10
# SafetyStockLevel           6
# ReorderPoint               6
# ListPrice                119
# Size                      18
# SizeRange                 11
# Weight                   127
# DaysToManufacture          4
# ProductLine                4
# DealerPrice              120
# Class                      3
# Style                      3
# ModelName                119
# LargePhoto                42
# EnglishDescription       114
# FrenchDescription        113
# ChineseDescription       113
# ArabicDescription        113
# HebrewDescription        113
# ThaiDescription          113
# GermanDescription        113
# JapaneseDescription      114
# TurkishDescription       114
# StartDate                  4
# EndDate                    2
# Status                     1
# dtype: int64

# %%
query = 'select * from dimproduct'
df=pd.read_sql(query,db_engine)
df.iloc[3]
# Out:
# ProductKey                                                               4
# ProductAlternateKey                                                BE-2908
# ProductSubcategoryKey                                                  NaN
# WeightUnitMeasureCode                                                 None
# SizeUnitMeasureCode                                                   None
# EnglishProductName                                   Headset Ball Bearings
# SpanishProductName
# FrenchProductName
# StandardCost                                                           NaN
# FinishedGoodsFlag                                                        0
# Color                                                                   NA
# SafetyStockLevel                                                       800
# ReorderPoint                                                           600
# ListPrice                                                              NaN
# Size                                                                  None
# SizeRange                                                               NA
# Weight                                                                 NaN
# DaysToManufacture                                                        0
# ProductLine                                                           None
# DealerPrice                                                            NaN
# Class                                                                 None
# Style                                                                 None
# ModelName                                                             None
# LargePhoto               b'GIF89a\xf0\x00\x95\x00\xf7\x00\x00\x00\x00\x...
# EnglishDescription                                                    None
# FrenchDescription                                                     None
# ChineseDescription                                                    None
# ArabicDescription                                                     None
# HebrewDescription                                                     None
# ThaiDescription                                                       None
# GermanDescription                                                     None
# JapaneseDescription                                                   None
# TurkishDescription                                                    None
# StartDate                                              2003-07-01 00:00:00
# EndDate                                                                NaT
# Status                                                             Current
# Name: 3, dtype: object

# %%
query = 'select * from dimproduct'
df=pd.read_sql(query,db_engine)
df['EnglishProductName'].unique()
# Out:
# array(['Adjustable Race', 'Bearing Ball', 'BB Ball Bearing',
#        'Headset Ball Bearings', 'Blade', 'LL Crankarm', 'ML Crankarm',
#        'HL Crankarm', 'Chainring Bolts', 'Chainring Nut', 'Chainring',
#        'Crown Race', 'Chain Stays', 'Decal 1', 'Decal 2', 'Down Tube',
#        'Mountain End Caps', 'Road End Caps', 'Touring End Caps',
#        'Fork End', 'Freewheel', 'Flat Washer 1', 'Flat Washer 6',
#        'Flat Washer 2', 'Flat Washer 9', 'Flat Washer 4', 'Flat Washer 3',
#        'Flat Washer 8', 'Flat Washer 5', 'Flat Washer 7', 'Fork Crown',
#        'Front Derailleur Cage', 'Front Derailleur Linkage',
#        'Guide Pulley', 'LL Grip Tape', 'ML Grip Tape', 'HL Grip Tape',
#        'Thin-Jam Hex Nut 9', 'Thin-Jam Hex Nut 10', 'Thin-Jam Hex Nut 1',
#        'Thin-Jam Hex Nut 2', 'Thin-Jam Hex Nut 15', 'Thin-Jam Hex Nut 16',
#        'Thin-Jam Hex Nut 5', 'Thin-Jam Hex Nut 6', 'Thin-Jam Hex Nut 3',
#        'Thin-Jam Hex Nut 4', 'Thin-Jam Hex Nut 13', 'Thin-Jam Hex Nut 14',
#        'Thin-Jam Hex Nut 7', 'Thin-Jam Hex Nut 8', 'Thin-Jam Hex Nut 12',
#        'Thin-Jam Hex Nut 11', 'Hex Nut 5', 'Hex Nut 6', 'Hex Nut 16',
#        'Hex Nut 17', 'Hex Nut 7', 'Hex Nut 8', 'Hex Nut 9', 'Hex Nut 22',
#        'Hex Nut 23', 'Hex Nut 12', 'Hex Nut 13', 'Hex Nut 1',
#        'Hex Nut 10', 'Hex Nut 11', 'Hex Nut 2', 'Hex Nut 20',
#        'Hex Nut 21', 'Hex Nut 3', 'Hex Nut 14', 'Hex Nut 15', 'Hex Nut 4',
#        'Hex Nut 18', 'Hex Nut 19', 'Handlebar Tube', 'Head Tube',
#        'LL Hub', 'HL Hub', 'Keyed Washer', 'External Lock Washer 3',
#        'External Lock Washer 4', 'External Lock Washer 9',
#        'External Lock Washer 5', 'External Lock Washer 7',
#        'External Lock Washer 6', 'External Lock Washer 1',
#        'External Lock Washer 8', 'External Lock Washer 2',
#        'Internal Lock Washer 3', 'Internal Lock Washer 4',
#        'Internal Lock Washer 9', 'Internal Lock Washer 5',
#        'Internal Lock Washer 7', 'Internal Lock Washer 6',
#        'Internal Lock Washer 10', 'Internal Lock Washer 1',
#        'Internal Lock Washer 8', 'Internal Lock Washer 2',
#        'Thin-Jam Lock Nut 9', 'Thin-Jam Lock Nut 10',
#        'Thin-Jam Lock Nut 1', 'Thin-Jam Lock Nut 2',
#        'Thin-Jam Lock Nut 15', 'Thin-Jam Lock Nut 16',
#        'Thin-Jam Lock Nut 5', 'Thin-Jam Lock Nut 6',
#        'Thin-Jam Lock Nut 3', 'Thin-Jam Lock Nut 4',
#        'Thin-Jam Lock Nut 13', 'Thin-Jam Lock Nut 14',
#        'Thin-Jam Lock Nut 7', 'Thin-Jam Lock Nut 8',
#        'Thin-Jam Lock Nut 12', 'Thin-Jam Lock Nut 11', 'Lock Nut 5',
#        'Lock Nut 6', 'Lock Nut 16', 'Lock Nut 17', 'Lock Nut 7',
#        'Lock Nut 8', 'Lock Nut 9', 'Lock Nut 22', 'Lock Nut 23',
#        'Lock Nut 12', 'Lock Nut 13', 'Lock Nut 1', 'Lock Nut 10',
#        'Lock Nut 11', 'Lock Nut 2', 'Lock Nut 20', 'Lock Nut 21',
#        'Lock Nut 3', 'Lock Nut 14', 'Lock Nut 15', 'Lock Nut 4',
#        'Lock Nut 19', 'Lock Nut 18', 'Lock Ring', 'Lower Head Race',
#        'Lock Washer 4', 'Lock Washer 5', 'Lock Washer 10',
#        'Lock Washer 6', 'Lock Washer 13', 'Lock Washer 8',
#        'Lock Washer 1', 'Lock Washer 7', 'Lock Washer 12',
#        'Lock Washer 2', 'Lock Washer 9', 'Lock Washer 3',
#        'Lock Washer 11', 'Metal Angle', 'Metal Bar 1', 'Metal Bar 2',
#        'Metal Plate 2', 'Metal Plate 1', 'Metal Plate 3', 'Metal Sheet 2',
#        'Metal Sheet 3', 'Metal Sheet 7', 'Metal Sheet 4', 'Metal Sheet 5',
#        'Metal Sheet 6', 'Metal Sheet 1', 'Metal Tread Plate', 'LL Nipple',
#        'HL Nipple', 'Paint - Black', 'Paint - Red', 'Paint - Silver',
#        'Paint - Blue', 'Paint - Yellow', 'Pinch Bolt', 'Cup-Shaped Race',
#        'Cone-Shaped Race', 'Reflector', 'LL Mountain Rim',
#        'ML Mountain Rim', 'HL Mountain Rim', 'LL Road Rim', 'ML Road Rim',
#        'HL Road Rim', 'Touring Rim', 'LL Mountain Seat Assembly',
#        'ML Mountain Seat Assembly', 'HL Mountain Seat Assembly',
#        'LL Road Seat Assembly', 'ML Road Seat Assembly',
#        'HL Road Seat Assembly', 'LL Touring Seat Assembly',
#        'ML Touring Seat Assembly', 'HL Touring Seat Assembly',
#        'LL Spindle/Axle', 'HL Spindle/Axle', 'LL Shell', 'HL Shell',
#        'Spokes', 'Seat Lug', 'Stem', 'Seat Post', 'Steerer', 'Seat Stays',
#        'Seat Tube', 'Top Tube', 'Tension Pulley', 'Rear Derailleur Cage',
#        'HL Road Frame - Black, 58', 'HL Road Frame - Red, 58',
#        'Sport-100 Helmet, Red', 'Sport-100 Helmet, Black',
#        'Mountain Bike Socks, M', 'Mountain Bike Socks, L',
#        'Sport-100 Helmet, Blue', 'AWC Logo Cap',
#        'Long-Sleeve Logo Jersey, S', 'Long-Sleeve Logo Jersey, M',
#        'Long-Sleeve Logo Jersey, L', 'Long-Sleeve Logo Jersey, XL',
#        'HL Road Frame - Red, 62', 'HL Road Frame - Red, 44',
#        'HL Road Frame - Red, 48', 'HL Road Frame - Red, 52',
#        'HL Road Frame - Red, 56', 'LL Road Frame - Black, 58',
#        'LL Road Frame - Black, 60', 'LL Road Frame - Black, 62',
#        'LL Road Frame - Red, 44', 'LL Road Frame - Red, 48',
#        'LL Road Frame - Red, 52', 'LL Road Frame - Red, 58',
#        'LL Road Frame - Red, 60', 'LL Road Frame - Red, 62',
#        'ML Road Frame - Red, 44', 'ML Road Frame - Red, 48',
#        'ML Road Frame - Red, 52', 'ML Road Frame - Red, 58',
#        'ML Road Frame - Red, 60', 'LL Road Frame - Black, 44',
#        'LL Road Frame - Black, 48', 'LL Road Frame - Black, 52',
#        'HL Mountain Frame - Silver, 42', 'HL Mountain Frame - Silver, 44',
#        'HL Mountain Frame - Silver, 48', 'HL Mountain Frame - Silver, 46',
#        'HL Mountain Frame - Black, 42', 'HL Mountain Frame - Black, 44',
#        'HL Mountain Frame - Black, 48', 'HL Mountain Frame - Black, 46',
#        'HL Mountain Frame - Black, 38', 'HL Mountain Frame - Silver, 38',
#        'Road-150 Red, 62', 'Road-150 Red, 44', 'Road-150 Red, 48',
#        'Road-150 Red, 52', 'Road-150 Red, 56', 'Road-450 Red, 58',
#        'Road-450 Red, 60', 'Road-450 Red, 44', 'Road-450 Red, 48',
#        'Road-450 Red, 52', 'Road-650 Red, 58', 'Road-650 Red, 60',
#        'Road-650 Red, 62', 'Road-650 Red, 44', 'Road-650 Red, 48',
#        'Road-650 Red, 52', 'Road-650 Black, 58', 'Road-650 Black, 60',
#        'Road-650 Black, 62', 'Road-650 Black, 44', 'Road-650 Black, 48',
#        'Road-650 Black, 52', 'Mountain-100 Silver, 38',
#        'Mountain-100 Silver, 42', 'Mountain-100 Silver, 44',
#        'Mountain-100 Silver, 48', 'Mountain-100 Black, 38',
#        'Mountain-100 Black, 42', 'Mountain-100 Black, 44',
#        'Mountain-100 Black, 48', 'Mountain-200 Silver, 38',
#        'Mountain-200 Silver, 42', 'Mountain-200 Silver, 46',
#        'Mountain-200 Black, 38', 'Mountain-200 Black, 42',
#        'Mountain-200 Black, 46', 'Mountain-300 Black, 38',
#        'Mountain-300 Black, 40', 'Mountain-300 Black, 44',
#        'Mountain-300 Black, 48', 'Road-250 Red, 44', 'Road-250 Red, 48',
#        'Road-250 Red, 52', 'Road-250 Red, 58', 'Road-250 Black, 44',
#        'Road-250 Black, 48', 'Road-250 Black, 52', 'Road-250 Black, 58',
#        'Road-550-W Yellow, 38', 'Road-550-W Yellow, 40',
#        'Road-550-W Yellow, 42', 'Road-550-W Yellow, 44',
#        'Road-550-W Yellow, 48', 'LL Fork', 'ML Fork', 'HL Fork',
#        'LL Headset', 'ML Headset', 'HL Headset', 'LL Mountain Handlebars',
#        'ML Mountain Handlebars', 'HL Mountain Handlebars',
#        'LL Road Handlebars', 'ML Road Handlebars', 'HL Road Handlebars',
#        'ML Mountain Frame - Black, 38', 'LL Mountain Front Wheel',
#        'ML Mountain Front Wheel', 'HL Mountain Front Wheel',
#        'LL Road Front Wheel', 'ML Road Front Wheel',
#        'HL Road Front Wheel', 'Touring Front Wheel',
#        'ML Road Frame-W - Yellow, 38', 'LL Mountain Rear Wheel',
#        'ML Mountain Rear Wheel', 'HL Mountain Rear Wheel',
#        'LL Road Rear Wheel', 'ML Road Rear Wheel', 'HL Road Rear Wheel',
#        'Touring Rear Wheel', 'ML Mountain Frame - Black, 40',
#        'ML Mountain Frame - Black, 44', 'ML Mountain Frame - Black, 48',
#        'ML Road Frame-W - Yellow, 40', 'ML Road Frame-W - Yellow, 42',
#        'ML Road Frame-W - Yellow, 44', 'ML Road Frame-W - Yellow, 48',
#        'HL Road Frame - Black, 62', 'HL Road Frame - Black, 44',
#        'HL Road Frame - Black, 48', 'HL Road Frame - Black, 52',
#        "Men's Sports Shorts, S", 'Touring-Panniers, Large', 'Cable Lock',
#        'Minipump', 'Mountain Pump', 'Taillights - Battery-Powered',
#        'Headlights - Dual-Beam', 'Headlights - Weatherproof',
#        "Men's Sports Shorts, M", "Men's Sports Shorts, L",
#        "Men's Sports Shorts, XL", "Women's Tights, S",
#        "Women's Tights, M", "Women's Tights, L", "Men's Bib-Shorts, S",
#        "Men's Bib-Shorts, M", "Men's Bib-Shorts, L",
#        'Half-Finger Gloves, S', 'Half-Finger Gloves, M',
#        'Half-Finger Gloves, L', 'Full-Finger Gloves, S',
#        'Full-Finger Gloves, M', 'Full-Finger Gloves, L',
#        'Classic Vest, S', 'Classic Vest, M', 'Classic Vest, L',
#        "Women's Mountain Shorts, S", "Women's Mountain Shorts, M",
#        "Women's Mountain Shorts, L", 'Water Bottle - 30 oz.',
#        'Mountain Bottle Cage', 'Road Bottle Cage', 'Patch Kit/8 Patches',
#        'Racing Socks, M', 'Racing Socks, L', 'Hitch Rack - 4-Bike',
#        'Bike Wash - Dissolver', 'Fender Set - Mountain',
#        'All-Purpose Bike Stand', 'Hydration Pack - 70 oz.',
#        'Short-Sleeve Classic Jersey, S', 'Short-Sleeve Classic Jersey, M',
#        'Short-Sleeve Classic Jersey, L',
#        'Short-Sleeve Classic Jersey, XL', 'HL Touring Frame - Yellow, 60',
#        'LL Touring Frame - Yellow, 62', 'HL Touring Frame - Yellow, 46',
#        'HL Touring Frame - Yellow, 50', 'HL Touring Frame - Yellow, 54',
#        'HL Touring Frame - Blue, 46', 'HL Touring Frame - Blue, 50',
#        'HL Touring Frame - Blue, 54', 'HL Touring Frame - Blue, 60',
#        'Rear Derailleur', 'LL Touring Frame - Blue, 50',
#        'LL Touring Frame - Blue, 54', 'LL Touring Frame - Blue, 58',
#        'LL Touring Frame - Blue, 62', 'LL Touring Frame - Yellow, 44',
#        'LL Touring Frame - Yellow, 50', 'LL Touring Frame - Yellow, 54',
#        'LL Touring Frame - Yellow, 58', 'LL Touring Frame - Blue, 44',
#        'ML Mountain Frame-W - Silver, 40',
#        'ML Mountain Frame-W - Silver, 42',
#        'ML Mountain Frame-W - Silver, 46', 'Rear Brakes',
#        'LL Mountain Seat/Saddle', 'ML Mountain Seat/Saddle',
#        'HL Mountain Seat/Saddle', 'LL Road Seat/Saddle',
#        'ML Road Seat/Saddle', 'HL Road Seat/Saddle',
#        'LL Touring Seat/Saddle', 'ML Touring Seat/Saddle',
#        'HL Touring Seat/Saddle', 'LL Mountain Frame - Silver, 42',
#        'LL Mountain Frame - Silver, 44', 'LL Mountain Frame - Silver, 48',
#        'LL Mountain Frame - Silver, 52', 'Mountain Tire Tube',
#        'Road Tire Tube', 'Touring Tire Tube',
#        'LL Mountain Frame - Black, 42', 'LL Mountain Frame - Black, 44',
#        'LL Mountain Frame - Black, 48', 'LL Mountain Frame - Black, 52',
#        'LL Mountain Tire', 'ML Mountain Tire', 'HL Mountain Tire',
#        'LL Road Tire', 'ML Road Tire', 'HL Road Tire', 'Touring Tire',
#        'LL Mountain Pedal', 'ML Mountain Pedal', 'HL Mountain Pedal',
#        'LL Road Pedal', 'ML Road Pedal', 'HL Road Pedal', 'Touring Pedal',
#        'ML Mountain Frame-W - Silver, 38',
#        'LL Mountain Frame - Black, 40', 'LL Mountain Frame - Silver, 40',
#        'Front Derailleur', 'LL Touring Handlebars',
#        'HL Touring Handlebars', 'Front Brakes', 'LL Crankset',
#        'ML Crankset', 'HL Crankset', 'Chain', 'Touring-2000 Blue, 60',
#        'Touring-1000 Yellow, 46', 'Touring-1000 Yellow, 50',
#        'Touring-1000 Yellow, 54', 'Touring-1000 Yellow, 60',
#        'Touring-3000 Blue, 54', 'Touring-3000 Blue, 58',
#        'Touring-3000 Blue, 62', 'Touring-3000 Yellow, 44',
#        'Touring-3000 Yellow, 50', 'Touring-3000 Yellow, 54',
#        'Touring-3000 Yellow, 58', 'Touring-3000 Yellow, 62',
#        'Touring-1000 Blue, 46', 'Touring-1000 Blue, 50',
#        'Touring-1000 Blue, 54', 'Touring-1000 Blue, 60',
#        'Touring-2000 Blue, 46', 'Touring-2000 Blue, 50',
#        'Touring-2000 Blue, 54', 'Road-350-W Yellow, 40',
#        'Road-350-W Yellow, 42', 'Road-350-W Yellow, 44',
#        'Road-350-W Yellow, 48', 'Road-750 Black, 58',
#        'Touring-3000 Blue, 44', 'Touring-3000 Blue, 50',
#        'Mountain-400-W Silver, 38', 'Mountain-400-W Silver, 40',
#        'Mountain-400-W Silver, 42', 'Mountain-400-W Silver, 46',
#        'Mountain-500 Silver, 40', 'Mountain-500 Silver, 42',
#        'Mountain-500 Silver, 44', 'Mountain-500 Silver, 48',
#        'Mountain-500 Silver, 52', 'Mountain-500 Black, 40',
#        'Mountain-500 Black, 42', 'Mountain-500 Black, 44',
#        'Mountain-500 Black, 48', 'Mountain-500 Black, 52',
#        'LL Bottom Bracket', 'ML Bottom Bracket', 'HL Bottom Bracket',
#        'Road-750 Black, 44', 'Road-750 Black, 48', 'Road-750 Black, 52'],
#       dtype=object)

# %%
query = 'select * from dimproduct'
df=pd.read_sql(query,db_engine)
df['EnglishProductName'].value_counts()
# Out:
# EnglishProductName
# LL Road Frame - Black, 44         3
# HL Mountain Frame - Silver, 42    3
# LL Road Frame - Black, 48         3
# Sport-100 Helmet, Blue            3
# AWC Logo Cap                      3
#                                  ..
# Fork End                          1
# Freewheel                         1
# Flat Washer 1                     1
# Flat Washer 6                     1
# Mountain-400-W Silver, 46         1
# Name: count, Length: 504, dtype: int64
